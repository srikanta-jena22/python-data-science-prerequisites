# %%
# Integers, floats, strings
x = 10
pi = 3.1415
name = "Srikanta"

# Lists(mutable)
fruits = ["Apple", "Banana", "Orange"]

# Tuples (immutable, elements can be immutable or mutable)
marks = (39, 45)

# Sets (unique values, itself is mutable but elements inside a set are immutable)
nums = {1, 2, 2, 3, 4}

# Dictionaries(key:value pair , itself are mutable , but keys can be immutable)
student = {"name": "Srikanta", "age": 20, "grade": "A"}

#type is used to determine the type
print(type(x), type(fruits), type(student))
# Out:
# <class 'int'> <class 'list'> <class 'dict'>

# %%
#create a dict with your name,age and hobbies
personal_details={
    "name":"Srikanta",
    "age":20,
    "hobbies":["Playing Chess","Gym"]
}
print(personal_details["hobbies"][1])

#create a list with duplicate elements and make it a set
lst=[1,2,3,2,2,1,4,5]
print(set(lst))

#swap values between two variables without creating a temp variable
x,y=5,6
print("Before swapping (x,y): ",x,y)
x,y=y,x
print("After swapping (x,y): ",x,y)

#read a sentence from the user and find the total no. of unique words in it , also display all the unique words along with their frequencies
sentence = input("Enter a sentence: ")
words = sentence.split()
unique_words = set(words)
frequency = {}
for word in words:
    frequency[word] = frequency.get(word, 0) + 1
print("\nUnique words:", unique_words)
print("Number of unique words:", len(unique_words))
print("Word frequencies:", frequency)

#rotate a list k steps to the right
def rotate(lst,k):
    k%=len(lst)
    return lst[k:]+lst[:k]
print(rotate([1,2,3,4,5,6],4))
# Out:
# Gym
# {1, 2, 3, 4, 5}
# Before swapping (x,y):  5 6
# After swapping (x,y):  6 5
#
# Unique words: {'dadfenwnf'}
# Number of unique words: 1
# Word frequencies: {'dadfenwnf': 1}
# [5, 6, 1, 2, 3, 4]
